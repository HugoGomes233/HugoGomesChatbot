# %% [markdown]
# ### First LangChain Project
# This project was meant to explore Azure OpenAI a little bit and create a simple chatbot that actively answers questions.
#
# *This bot does not retain conversation history and only answers questions independently.

# %%
# !pip install openai #Install SDK of Azure OpenAI
# !pip install python-dotenv # Install dotenv to be able to acess .env variables

# %%
import os
from dotenv import load_dotenv

#load .env
load_dotenv()
# Out:
# True

# %%
import os
from openai import AzureOpenAI

# Load environment variables
endpoint = os.getenv("AZURE_ENDPOINT")
deployment = os.getenv("AZURE_DEPLOYMENT")
subscription_key = os.getenv("AZURE_OPENAI_KEY")
api_version = os.getenv("AZURE_API_VERSION")

# Initialize Azure OpenAI client
client = AzureOpenAI(
    api_version=api_version,
    azure_endpoint=endpoint,
    api_key=subscription_key,
)

print("Chatbot is running! Type 'exit' or 'quit' to stop.")

# Keep conversation going until user wants to exit
while True:
    user_input = input("\nYou: ")
    
    # Exit condition
    if user_input.lower() in ["exit", "quit"]:
        print("Goodbye!")
        break
    
    # Prepare messages for the model
    messages = [
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": user_input}
    ]
    
    # Request response from Azure OpenAI
    response = client.chat.completions.create(
        messages=messages,
        model=deployment
    )
    
    # Print the assistant's answer
    print("Assistant:", response.choices[0].message.content)
